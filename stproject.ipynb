# %% [markdown]
# <a href="https://colab.research.google.com/github/ParneetKaurDhanoa/data-science/blob/main/stproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #code

# %%
df=pd.read_csv('/content/drive/MyDrive/house price prediction.csv')

# %%
df.head()
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 00:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.describe(include="all")
#checking statstical summary of our whole dataset
# Out:
#                     date         price     bedrooms    bathrooms  \
# count               4600  4.600000e+03  4600.000000  4600.000000
# unique                70           NaN          NaN          NaN
# top     23-06-2014 00:00           NaN          NaN          NaN
# freq                 142           NaN          NaN          NaN
# mean                 NaN  5.519630e+05     3.400870     2.160815
# std                  NaN  5.638347e+05     0.908848     0.783781
# min                  NaN  0.000000e+00     0.000000     0.000000
# 25%                  NaN  3.228750e+05     3.000000     1.750000
# 50%                  NaN  4.609435e+05     3.000000     2.250000
# 75%                  NaN  6.549625e+05     4.000000     2.500000
# max                  NaN  2.659000e+07     9.000000     8.000000
#
#          sqft_living      sqft_lot       floors   waterfront         view  \
# count    4600.000000  4.600000e+03  4600.000000  4600.000000  4600.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.nunique()
# Out:
# date               70
# price            1741
# bedrooms           10
# bathrooms          26
# sqft_living       566
# sqft_lot         3113
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        511
# sqft_basement     207
# yr_built          115
# yr_renovated       60
# street           4525
# city               44
# statezip           77
# country             1
# dtype: int64

# %%
df.replace("?", np.nan, inplace = True)
df.head()
#Replacing empty values that contains '?' with NaN so that we can apply data cleaning
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 00:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
missing_data=df.isnull()
missing_data.head()
#Checking if there are any null values in our dataset
# Out:
#     date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  False  False     False      False        False     False   False
# 1  False  False     False      False        False     False   False
# 2  False  False     False      False        False     False   False
# 3  False  False     False      False        False     False   False
# 4  False  False     False      False        False     False   False
#
#    waterfront   view  condition  sqft_above  sqft_basement  yr_built  \
# 0       False  False      False       False          False     False
# 1       False  False      False       False          False     False
# 2       False  False      False       False          False     False
# 3       False  False      False       False          False     False
# 4       False  False      False       False          False     False
#
#    yr_renovated  street   city  statezip  country
# 0         False   False  False     False    False
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#df["statezip"].drop
#df["street"].drop
#df["date"].drop

# %%
df=df.drop(["date","statezip","waterfront","sqft_lot","country","city"],axis=1)

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0   313000.0         3       1.50         1340     1.5     0          3
# 1  2384000.0         5       2.50         3650     2.0     4          5
# 2   342000.0         3       2.00         1930     1.0     0          4
# 3   420000.0         3       2.25         2000     1.0     0          4
# 4   550000.0         4       2.50         1940     1.0     0          4
#
#    sqft_above  sqft_basement  yr_built  yr_renovated                    street
# 0        1340              0      1955          2005      18810 Densmore Ave N
# 1        3370            280      1921             0           709 W Blaine St
# 2        1930              0      1966             0  26206-26214 143rd Ave SE
# 3        1000           1000      1963             0           857 170th Pl NE
# 4        1140            800      1976          1992         9105 170th Ave NE

# %%
df.shape
# Out:
# (4600, 12)

# %%
buildings_age=(2022-df["yr_built"])
print(buildings_age)
# Out:
# 0        67
# 1       101
# 2        56
# 3        59
# 4        46
#        ...
# 4595     68
# 4596     39
# 4597     13
# 4598     48
# 4599     32
# Name: yr_built, Length: 4600, dtype: int64

# %%
yr_renovated_ago=(2022-df["yr_renovated"])
print(yr_renovated_ago)
# Out:
# 0         17
# 1       2022
# 2       2022
# 3       2022
# 4         30
#         ...
# 4595      43
# 4596      13
# 4597    2022
# 4598    2022
# 4599    2022
# Name: yr_renovated, Length: 4600, dtype: int64

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0   313000.0         3       1.50         1340     1.5     0          3
# 1  2384000.0         5       2.50         3650     2.0     4          5
# 2   342000.0         3       2.00         1930     1.0     0          4
# 3   420000.0         3       2.25         2000     1.0     0          4
# 4   550000.0         4       2.50         1940     1.0     0          4
#
#    sqft_above  sqft_basement  yr_built  yr_renovated                    street
# 0        1340              0      1955          2005      18810 Densmore Ave N
# 1        3370            280      1921             0           709 W Blaine St
# 2        1930              0      1966             0  26206-26214 143rd Ave SE
# 3        1000           1000      1963             0           857 170th Pl NE
# 4        1140            800      1976          1992         9105 170th Ave NE

# %%
x=df["bedrooms"]
y=df["price"]
plt.scatter(x,y)
plt.show()

# %%
x=df["bathrooms"]
y=df["price"]
plt.scatter(x,y)
plt.show()

# %%
plt.hist(df["price"])
plt.show()

# %%
df = df.assign(age_of_building = buildings_age)
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0     3.130000e+05         3       1.50         1340     1.5     0          3
# 1     2.384000e+06         5       2.50         3650     2.0     4          5
# 2     3.420000e+05         3       2.00         1930     1.0     0          4
# 3     4.200000e+05         3       2.25         2000     1.0     0          4
# 4     5.500000e+05         4       2.50         1940     1.0     0          4
# ...            ...       ...        ...          ...     ...   ...        ...
# 4595  3.081667e+05         3       1.75         1510     1.0     0          4
# 4596  5.343333e+05         3       2.50         1460     2.0     0          3
# 4597  4.169042e+05         3       2.50         3010     2.0     0          3
# 4598  2.034000e+05         4       2.00         2090     1.0     0          3
# 4599  2.206000e+05         3       2.50         1490     2.0     0          4
#
# ...

# %%
df=df.drop(["yr_built"],axis=1)
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0   313000.0         3       1.50         1340     1.5     0          3
# 1  2384000.0         5       2.50         3650     2.0     4          5
# 2   342000.0         3       2.00         1930     1.0     0          4
# 3   420000.0         3       2.25         2000     1.0     0          4
# 4   550000.0         4       2.50         1940     1.0     0          4
#
#    sqft_above  sqft_basement  yr_renovated                    street  \
# 0        1340              0          2005      18810 Densmore Ave N
# 1        3370            280             0           709 W Blaine St
# 2        1930              0             0  26206-26214 143rd Ave SE
# 3        1000           1000             0           857 170th Pl NE
# 4        1140            800          1992         9105 170th Ave NE
#
#    age_of_building
# 0               67
# 1              101
# 2               56
# 3               59
# ...

# %%
df = df.assign(renovation_years = yr_renovated_ago)

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0   313000.0         3       1.50         1340     1.5     0          3
# 1  2384000.0         5       2.50         3650     2.0     4          5
# 2   342000.0         3       2.00         1930     1.0     0          4
# 3   420000.0         3       2.25         2000     1.0     0          4
# 4   550000.0         4       2.50         1940     1.0     0          4
#
#    sqft_above  sqft_basement  yr_renovated                    street  \
# 0        1340              0          2005      18810 Densmore Ave N
# 1        3370            280             0           709 W Blaine St
# 2        1930              0             0  26206-26214 143rd Ave SE
# 3        1000           1000             0           857 170th Pl NE
# 4        1140            800          1992         9105 170th Ave NE
#
#    age_of_building  renovation_years
# 0               67                17
# 1              101              2022
# ...

# %%
df=df.drop(["renovation_years","yr_renovated"],axis=1)
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0   313000.0         3       1.50         1340     1.5     0          3
# 1  2384000.0         5       2.50         3650     2.0     4          5
# 2   342000.0         3       2.00         1930     1.0     0          4
# 3   420000.0         3       2.25         2000     1.0     0          4
# 4   550000.0         4       2.50         1940     1.0     0          4
#
#    sqft_above  sqft_basement                    street  age_of_building
# 0        1340              0      18810 Densmore Ave N               67
# 1        3370            280           709 W Blaine St              101
# 2        1930              0  26206-26214 143rd Ave SE               56
# 3        1000           1000           857 170th Pl NE               59
# 4        1140            800         9105 170th Ave NE               46

# %%
x=df["age_of_building"]
y=df["price"]
plt.scatter(x,y)
plt.show()

# %%
df["bathrooms"].dtype
# Out:
# dtype('float64')

# %%
df["bathrooms"] = df["bathrooms"].astype(int)

# %%
df["floors"] = df["floors"].astype(int)

# %%
df=df.drop(["view"],axis=1)

# %%
df["price"]
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
df["price"].replace("e+","00",inplace=True)
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  floors  condition  \
# 0     3.130000e+05         3          1         1340       1          3
# 1     2.384000e+06         5          2         3650       2          5
# 2     3.420000e+05         3          2         1930       1          4
# 3     4.200000e+05         3          2         2000       1          4
# 4     5.500000e+05         4          2         1940       1          4
# ...            ...       ...        ...          ...     ...        ...
# 4595  3.081667e+05         3          1         1510       1          4
# 4596  5.343333e+05         3          2         1460       2          3
# 4597  4.169042e+05         3          2         3010       2          3
# 4598  2.034000e+05         4          2         2090       1          3
# 4599  2.206000e+05         3          2         1490       2          4
#
#       sqft_above  sqft_basement                    street  age_of_building
# ...

# %%
t=df['condition']
plt.boxplot(t)
plt.show()

# %%
x=df['street']
y=df['price']
plt.scatter(x,y)
plt.show()

# %%
x=df['street']
y=df['price']
plt.bar(x[0:10],y[0:10])
plt.show()

# %%
df["price"].mean()
# Out:
# 551962.9884730434

# %%
df["price"].std()
# Out:
# 563834.702546812

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of              price  bedrooms  bathrooms  sqft_living  floors  condition  \
# 0     3.130000e+05         3          1         1340       1          3
# 1     2.384000e+06         5          2         3650       2          5
# 2     3.420000e+05         3          2         1930       1          4
# 3     4.200000e+05         3          2         2000       1          4
# 4     5.500000e+05         4          2         1940       1          4
# ...            ...       ...        ...          ...     ...        ...
# 4595  3.081667e+05         3          1         1510       1          4
# 4596  5.343333e+05         3          2         1460       2          3
# 4597  4.169042e+05         3          2         3010       2          3
# 4598  2.034000e+05         4          2         2090       1          3
# 4599  2.206000e+05         3          2         1490       2          4
#
# ...

# %%
df.shape
# Out:
# (4600, 10)

# %%
df=df.drop(["sqft_basement","street"],axis=1)

# %%
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  floors  condition  \
# 0     3.130000e+05         3          1         1340       1          3
# 1     2.384000e+06         5          2         3650       2          5
# 2     3.420000e+05         3          2         1930       1          4
# 3     4.200000e+05         3          2         2000       1          4
# 4     5.500000e+05         4          2         1940       1          4
# ...            ...       ...        ...          ...     ...        ...
# 4595  3.081667e+05         3          1         1510       1          4
# 4596  5.343333e+05         3          2         1460       2          3
# 4597  4.169042e+05         3          2         3010       2          3
# 4598  2.034000e+05         4          2         2090       1          3
# 4599  2.206000e+05         3          2         1490       2          4
#
#       sqft_above  age_of_building
# 0           1340               67
# ...

# %%
sns.distplot(df['bedrooms'])
# Out:
# <ipython-input-44-04ce28449316>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedrooms'])
# <Axes: xlabel='bedrooms', ylabel='Density'>

# %%
sns.distplot(df['bathrooms'])
# Out:
# <ipython-input-45-c6a870d0f699>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathrooms'])
# <Axes: xlabel='bathrooms', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
x=df["bathrooms"]
y=df['price']

# %%
x.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    2
# Name: bathrooms, dtype: int64

# %%
y.head()
# Out:
# 0     313000.0
# 1    2384000.0
# 2     342000.0
# 3     420000.0
# 4     550000.0
# Name: price, dtype: float64

# %%
#using np.random.rand() function
n = np.random.rand(len(df)) < 0.8
train = df[n]
test = df[~n]

# %%
#checking train dataset distribuition using scatter plot
plt.scatter(train.bathrooms, train.price,  color='blue')
plt.xlabel("bathrooms")
plt.ylabel("price")
plt.show()

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
#linear regression object

# %%
#train_x is the predictor variable
train_x = train[['bathrooms']]
#train_y is the target variable
train_y = train[['price']]

# %%
regr.fit(train_x, train_y)
#fit the model
# Out:
# LinearRegression()

# %%
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[235598.72038781]]
# Intercept:  [132495.84341559]

# %%
#plot fit line over data
plt.scatter(train.bathrooms, train.price,  color='blue')#for train dataset distribuition
plt.plot(train_x, regr.coef_*train_x + regr.intercept_,color='red')#for fit line with predictor variable and linear reg equation as parameters
plt.xlabel("bathrooms")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.metrics import r2_score
#test_x and test_y are predictor and target variables
test_x = test[['bathrooms']]
test_y = test[['price']]

#test_Y is the predicted value
prediction_y = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(prediction_y- test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((prediction_y - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , prediction_y) )
# Out:
# Mean absolute error: 217524.10
# Residual sum of squares (MSE): 114860819740.40
# R2-score: 0.23
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %% [markdown]
# #multiple regression

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()

# %%
#multiple predictor variables
x = train[['bedrooms','bathrooms']]
y =train[['price']]

# %%
regr.fit (x, y)
#fit the model
# Out:
# LinearRegression()

# %%
print ('Coefficients: ', regr.coef_)
print ('intercept: ', regr.intercept_)
# Out:
# Coefficients:  [[ 33895.95872535 215115.04315467]]
# intercept:  [53926.35132206]

# %%
#prediction
y_hat= regr.predict(test[['bedrooms','bathrooms']])

# %%
x = test[['bedrooms','bathrooms']]
y =test[['price']]
print("Residual sum of squares: %.2f"% np.mean((y_hat - y) ** 2))
# Out:
# Residual sum of squares: 113898952423.50
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
